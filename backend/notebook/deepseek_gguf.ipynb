# %%
from llama_cpp import Llama

llm = Llama.from_pretrained(
    repo_id="unsloth/DeepSeek-R1-GGUF",
    filename="DeepSeek-R1-UD-IQ1_S/DeepSeek-R1-UD-IQ1_S-00001-of-00003.gguf",
    local_dir="../data/models/deepseek/",
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 3
#       1 from llama_cpp import Llama
# ----> 3 llm = Llama.from_pretrained(
#       4     repo_id="unsloth/DeepSeek-R1-GGUF",
#       5     # filename="DeepSeek-R1-UD-IQ1_S/DeepSeek-R1-UD-IQ1_S-00001-of-00003.gguf",
#       6     filename="DeepSeek-R1-UD-IQ1_S-00001-of-00003.gguf",
#       7     local_dir="../data/models/deepseek/",
#       8 )
#
# File ~/workspace/backend/.venv/lib/python3.10/site-packages/llama_cpp/llama.py:2284, in Llama.from_pretrained(cls, repo_id, filename, additional_files, local_dir, local_dir_use_symlinks, cache_dir, **kwargs)
#    2281 matching_files = [file for file in file_list if fnmatch.fnmatch(file, filename)]  # type: ignore
#    2283 if len(matching_files) == 0:
# -> 2284     raise ValueError(
#    2285         f"No file found in {repo_id} that match {filename}\n\n"
# ...

# %%
llm.create_chat_completion(messages=[{"role": "user", "content": "オイラーの等式について詳しく教えてくれますか？"}])
