# %%
from dotenv import load_dotenv


load_dotenv()
# Out:
# True

# %%
from app.codeinterpreter.component.session import CodeInterpreterSession


async def main():
    # create a session
    session = CodeInterpreterSession(port=7777)
    await session.astart()

    # generate a response based on user input
    response = await session.generate_response(
        "Plot the bitcoin chart of 2023 YTD"
        # """三井のリハウスについて以下のフォーマットで回答して
        # ```
        # 資本金: {資本金を記入します}
        # 売上高: {売上高を記入します}
        # 代表: {会社代表を記入します}
        # ```
        # """
    )

    # output the response (text + image)
    print("AI: ", response.content)
    for file in response.files:
        file.show_image()

    # terminate the session
    await session.astop()

# %%
await main()
# Out:
# AI:  Here is the Bitcoin price chart for the year 2023. The x-axis represents the date and the y-axis represents the price in USD. Please note that the data is based on the closing price for each day.
# <PIL.Image.Image image mode=RGB size=1200x621>
