# %% [markdown]
# # ruptures の model
#
# - clinear
#     - 各セグメントの開始点と終了点を結ぶトレンドからの距離の大きさをコスト値とする
# - rbf
#     - 周辺(セグメント内の各点)の差分量をコスト値とする
# - ar
#     - ar モデルで予測したときの難しさ（残差の大きさ）をコスト値とする

# %%
import numpy
import pandas
from datetime import datetime

import seaborn as sns

from matplotlib import pyplot


sns.set_theme(font="IPAexGothic")
pyplot.rcParams["figure.figsize"] = (20, 10)

# %%
import ruptures as rpt

# %%
# segmentation algorithm
rpt.Pelt        # Dynp で所定時間に終わらなさそうなときに代替として使う / コスト関数の大きさを踏まえて pen(penalty value) を設定する
    # penalty は、SVM の幅みたいなもの
rpt.KernelCPD
    # linear, rbf, cosine コストについて、Dynp, Pelt の C実装/高速版
rpt.Binseg
rpt.Window      # 変化点を敏感に捕まえたい(window少なめ)、鈍感にさせたい(window多め)などのバリエーションをもたせるのに使える
    # window 幅単位で区切ってセグメント化する。window//2 がストライド
rpt.Dynp        # 最適解の参考値としてほしい、計算時間次第で変化点の数を調整する
rpt.BottomUp
# Out:
# ruptures.detection.bottomup.BottomUp

# %%
from protuna import (
    build_prophet_model,
    Evaluator,
    Limitter,
    BestEstimator,
    setup_df_index,
    setup_limit,
    convert_wareki_to_seireki,
)

# %%
g_start_date = datetime.now()
g_start_date.strftime("%Y/%m/%d %T")
# Out:
# '2023/10/25 09:23:32'

# %%
url="https://www.mof.go.jp/jgbs/reference/interest_rate/data/jgbcm_all.csv"
_df = pandas.read_csv(url, header=1, encoding="shift-jis")
_df.tail()
# Out:
#            基準日      1年     2年     3年     4年     5年     6年     7年     8年  \
# 12574  R5.9.25  -0.063  0.033  0.093  0.192  0.318  0.375  0.472  0.577
# 12575  R5.9.26  -0.063  0.034  0.093  0.193  0.317  0.379  0.490  0.596
# 12576  R5.9.27  -0.064  0.034   0.09  0.188  0.313  0.374  0.488  0.596
# 12577  R5.9.28  -0.055  0.044  0.104  0.209  0.331  0.395  0.507  0.615
# 12578  R5.9.29  -0.064  0.044  0.108  0.219  0.341  0.409  0.521  0.630
#
#           9年    10年    15年    20年    25年    30年    40年
# 12574  0.654  0.738  1.129  1.425  1.551  1.612   1.75
# 12575  0.669  0.752  1.133  1.429  1.555  1.619   1.75
# 12576  0.669  0.747  1.129  1.432  1.559  1.627  1.753
# 12577  0.692  0.765  1.142  1.441  1.567  1.634   1.76
# 12578  0.703  0.774  1.165  1.456  1.575  1.649  1.776

# %%
_df["ds"] = pandas.to_datetime(_df["基準日"].apply(convert_wareki_to_seireki))
_df[["基準日", "ds"]]
# Out:
#             基準日         ds
# 0      S49.9.24 1974-09-24
# 1      S49.9.25 1974-09-25
# 2      S49.9.26 1974-09-26
# 3      S49.9.27 1974-09-27
# 4      S49.9.28 1974-09-28
# ...         ...        ...
# 12574   R5.9.25 2023-09-25
# 12575   R5.9.26 2023-09-26
# 12576   R5.9.27 2023-09-27
# 12577   R5.9.28 2023-09-28
# 12578   R5.9.29 2023-09-29
#
# [12579 rows x 2 columns]

# %%
_df.replace('-', float('nan'), inplace=True)

# %%
_df.head(3)
# Out:
#         基準日      1年     2年     3年     4年     5年    6年    7年     8年     9年  \
# 0  S49.9.24  10.327  9.362   8.83  8.515  8.348  8.29  8.24  8.121  8.127
# 1  S49.9.25  10.333  9.364  8.831  8.516  8.348  8.29  8.24  8.121  8.127
# 2  S49.9.26   10.34  9.366  8.832  8.516  8.348  8.29  8.24  8.122  8.128
#
#    10年  15年  20年  25年  30年  40年         ds
# 0  NaN  NaN  NaN  NaN  NaN  NaN 1974-09-24
# 1  NaN  NaN  NaN  NaN  NaN  NaN 1974-09-25
# 2  NaN  NaN  NaN  NaN  NaN  NaN 1974-09-26

# %%
rate_cols = [col for col in _df.columns if col not in ["基準日", "ds"]]
rate_cols = ["1年", "5年", "10年", "20年"]
rate_cols
# Out:
# ['1年', '5年', '10年', '20年']

# %%
_df[rate_cols] = _df[rate_cols].astype(float)
_df.head(3)
# Out:
#         基準日      1年     2年     3年     4年     5年    6年    7年     8年     9年  \
# 0  S49.9.24  10.327  9.362   8.83  8.515  8.348  8.29  8.24  8.121  8.127
# 1  S49.9.25  10.333  9.364  8.831  8.516  8.348  8.29  8.24  8.121  8.127
# 2  S49.9.26  10.340  9.366  8.832  8.516  8.348  8.29  8.24  8.122  8.128
#
#    10年  15年  20年  25年  30年  40年         ds
# 0  NaN  NaN  NaN  NaN  NaN  NaN 1974-09-24
# 1  NaN  NaN  NaN  NaN  NaN  NaN 1974-09-25
# 2  NaN  NaN  NaN  NaN  NaN  NaN 1974-09-26

# %%
df = _df.copy()
df.index = pandas.to_datetime(df.ds)

df_weekly = df[rate_cols].resample("W-MON").mean()
df_weekly.plot()
pyplot.show()

# %%
df[["10年"]].dropna().head(3)
# Out:
#               10年
# ds
# 1986-07-05  5.103
# 1986-07-07  5.091
# 1986-07-08  5.123

# %%
df1 = df[["10年"]]["2020-01-01":]
df1.head(3)
# Out:
#               10年
# ds
# 2020-01-06 -0.025
# 2020-01-07 -0.008
# 2020-01-08 -0.013

# %%
model = "clinear"
# model = "linear"
# model = "ar"

# alg = rpt.Dynp(model=model).fit(df1.values)
alg = rpt.Pelt(model=model).fit(df1.values)
alg

# %%
len(df1)
# Out:
# 916

# %%
# pred_bkps = alg.predict(n_bkps=10)
pred_bkps = alg.predict(pen=0.01)
pred_bkps
# Out:
# [30,
#  40,
#  50,
#  60,
#  115,
#  250,
#  275,
#  345,
#  380,
#  445,
#  480,
#  515,
#  530,
#  540,
#  605,
#  640,
#  655,
#  720,
#  730,
#  740,
#  745,
#  750,
#  775,
#  780,
#  790,
#  795,
#  820,
#  840,
#  850,
#  870,
#  875,
#  916]

# %%
#  rpt.show.display(df1, [], pred_bkps, figsize=(12, 9))
# pyplot.show()

# %%
df1.head(3)
# Out:
#               10年
# ds
# 2020-01-06 -0.025
# 2020-01-07 -0.008
# 2020-01-08 -0.013

# %%
def plot_bkps(df: pandas.DataFrame, bkps: list[int]):
    signal: pandas.DataFrame = df.copy()
    n_samples, n_features = signal.shape

    fig, axes = pyplot.subplots(n_features, sharex=True)
    axes = [axes] if n_features == 1 else axes

    for ax, sig in zip(axes, signal.T):
        signal.plot(ax=ax)

        for bkp in bkps:
            x = signal.index[bkp - 1]
            ax.axvline(x=x, color="b", linewidth=2, linestyle="--", alpha=0.2)

    fig.tight_layout()
    fig.show()

# %%
plot_bkps(df=df1.copy(), bkps=pred_bkps)

# %% [markdown]
# # 以下、ライブラリコードの理解用

# %%
signal = df1.copy()

# %%
from numpy.linalg import lstsq

start = 0
end = 5
_signal = signal.values[:, 0].reshape(-1, 1)
_covar = _signal[:, 1:]

# %%
_signal[:5]
# Out:
# array([[-0.025],
#        [-0.008],
#        [-0.013],
#        [-0.003],
#        [-0.003]])

# %%
_covar[:5]
# Out:
# array([], shape=(5, 0), dtype=float64)

# %%
y, X = _signal[start:end], _covar[start:end]
a, residual, b, c = lstsq(X, y, rcond=None)

# %%
df1.head(5)
# Out:
#               10年
# ds
# 2020-01-06 -0.025
# 2020-01-07 -0.008
# 2020-01-08 -0.013
# 2020-01-09 -0.003
# 2020-01-10 -0.003

# %%
residual
# Out:
# array([0.000876])

# %%
b, c
# Out:
# (0, array([], dtype=float64))

# %%
(y ** 2).sum()
# Out:
# 0.0008760000000000002

# %%
from scipy.spatial.distance import pdist, squareform

# %%
K = pdist(signal, metric="sqeuclidean")

gamma = 1.0
# median heuristics
K_median = numpy.median(K)
if K_median != 0:
    # K /= K_median
    gamma = 1 / K_median
K *= gamma
numpy.clip(K, 1e-2, 1e2, K)  # clipping to avoid exponential under/overflow
_gram = numpy.exp(squareform(-K))

# %%
K_median
# Out:
# 0.030975999999999997

# %%
(squareform(K))
# Out:
# array([[0.00000000e+00, 1.00000000e-02, 1.00000000e-02, ...,
#         1.92401860e+01, 2.01478564e+01, 2.06095364e+01],
#        [1.00000000e-02, 0.00000000e+00, 1.00000000e-02, ...,
#         1.84021501e+01, 1.92900633e+01, 1.97418647e+01],
#        [1.00000000e-02, 1.00000000e-02, 0.00000000e+00, ...,
#         1.86466942e+01, 1.95404184e+01, 1.99951253e+01],
#        ...,
#        [1.92401860e+01, 1.84021501e+01, 1.86466942e+01, ...,
#         0.00000000e+00, 1.04597107e-02, 2.35343492e-02],
#        [2.01478564e+01, 1.92900633e+01, 1.95404184e+01, ...,
#         1.04597107e-02, 0.00000000e+00, 1.00000000e-02],
#        [2.06095364e+01, 1.97418647e+01, 1.99951253e+01, ...,
#         2.35343492e-02, 1.00000000e-02, 0.00000000e+00]])

# %%
import numpy as np
from numpy.lib.stride_tricks import as_strided

# Sample data
signal = np.array([0, 1, 2, 3, 4, 5, 6, 7])
order = 3

# Compute shape and strides
n_samples = len(signal)
strides = (signal.itemsize, signal.itemsize)
shape = (n_samples - order, order)

# Generate lagged variable using as_strided
lagged = as_strided(signal, shape=shape, strides=strides)
lagged
# Out:
# array([[0, 1, 2],
#        [1, 2, 3],
#        [2, 3, 4],
#        [3, 4, 5],
#        [4, 5, 6]])

# %%
strides
# Out:
# (8, 8)

# %%
# pad the first columns
lagged_after_padding = np.pad(lagged, ((order, 0), (0, 0)), mode="edge")
lagged_after_padding
# Out:
# array([[0, 1, 2],
#        [0, 1, 2],
#        [0, 1, 2],
#        [0, 1, 2],
#        [1, 2, 3],
#        [2, 3, 4],
#        [3, 4, 5],
#        [4, 5, 6]])

# %%
# add intercept
covar = np.c_[lagged_after_padding, np.ones(n_samples)]
covar
# Out:
# array([[0., 1., 2., 1.],
#        [0., 1., 2., 1.],
#        [0., 1., 2., 1.],
#        [0., 1., 2., 1.],
#        [1., 2., 3., 1.],
#        [2., 3., 4., 1.],
#        [3., 4., 5., 1.],
#        [4., 5., 6., 1.]])

# %%
signal[:order]
# Out:
# array([0, 1, 2])

# %%
signal[order]
# Out:
# 3

# %%
signal[:order] = signal[order]
signal
# Out:
# array([3, 3, 3, 3, 4, 5, 6, 7])

# %%
from scipy.signal import argrelmax


argrelmax([], mode="wrap")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/devuser/workspace/notebook/ruptures.ipynb Cell 46 line 4
#       <a href='vscode-notebook-cell://dev-container%....ipynb#X62sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> from scipy.signal import argrelmax
# ----> <a href='vscode-notebook-cell://dev-container%....ipynb#X62sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> argrelmax([], mode="wrap")
#
# File ~/workspace/backend/.venv/lib/python3.10/site-packages/scipy/signal/_peak_finding.py:194, in argrelmax(data, axis, order, mode)
#     140 def argrelmax(data, axis=0, order=1, mode='clip'):
#     141     """
#     142     Calculate the relative maxima of `data`.
#     143
#    (...)
#     192     (array([0]), array([1]))
#     193     """
# --> 194     return argrelextrema(data, np.greater, axis, order, mode)
#
# File ~/workspace/backend/.venv/lib/python3.10/site-packages/scipy/signal/_peak_finding.py:249, in argrelextrema(data, comparator, axis, order, mode)
#     197 def argrelextrema(data, comparator, axis=0, order=1, mode='clip'):
#     198     """
#     199     Calculate the relative extrema of `data`.
#     200
#    (...)
#     247
#     248     """
# --> 249     results = _boolrelextrema(data, comparator,
#     250                               axis, order, mode)
#     251     return np.nonzero(results)
#
# File ~/workspace/backend/.venv/lib/python3.10/site-packages/scipy/signal/_peak_finding.py:67, in _boolrelextrema(data, comparator, axis, order, mode)
#      64 if (int(order) != order) or (order < 1):
#      65     raise ValueError('Order must be an int >= 1')
# ---> 67 datalen = data.shape[axis]
#      68 locs = np.arange(0, datalen)
#      70 results = np.ones(data.shape, dtype=bool)
#
# AttributeError: 'list' object has no attribute 'shape'
